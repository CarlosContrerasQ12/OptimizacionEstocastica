# %%
using Gridap
using GridapGmsh
using Gridap.FESpaces
using Gridap.Geometry
using PyCall
using PyPlot
using JLD
using StatsBase

# %%
function solucion_en_malla(Ω,uh)
    ndcel=Ω.grid.cell_node_ids
    ndcoor=Ω.grid.node_coordinates
    u=zeros(length(ndcel))
    sols=uh.cell_dof_values
    for i in 1:length(ndcel)
        for j in 1:length(sols[i])
            u[ndcel[i][j]]=sols[i][j]
        end
    end    
    return ndcoor,u
end

function pasar_a_cartesianas(ndcoor,u,dx,dy)
    x=Int[]
    y=Int[]
    for nod in ndcoor
        append!(x,Int(round(nod[1]/dx))+1)
        append!(y,Int(round(nod[2]/dy))+1)
    end
    matA=zeros(maximum(x),maximum(y))
    for i in 1:length(ndcoor)
        matA[x[i],y[i]]=u[i]
    end
    return matA
end
# Out:
# pasar_a_cartesianas (generic function with 1 method)

# %%
function resolver_calor(Pec,T_1,T_2,S,va,model,V0,Ω,dΩ,Γ,dΓ,dx,dy,dt,Tf)
    g1(x,t::Real)=T_1(t)
    g1(t::Real) = x -> g1(x,t)
    g2(x,t::Real)=T_2(t)
    g2(t::Real) = x -> g2(x,t)
    Ug = TransientTrialFESpace(V0,[g1,g2])

    m(t,u,v) = ∫( u*v )dΩ
    a(t,u,v) = (1.0/Pec)*∫( (∇(u)⋅∇(v)) )dΩ +∫( (va(t)⋅(∇(u)))*v)dΩ
    b(t,v) = ∫( S(t)*v )dΩ
    op_Af = TransientAffineFEOperator(m,a,b,Ug,V0)    
    linear_solver = LUSolver()
    Δt = dt
    θ = 0.5
    ode_solver = ThetaMethod(linear_solver,Δt,θ)
    u₀ = interpolate_everywhere(0.0,Ug(0.0))
    t₀ = 0.0
    T = Tf
    uₕₜ= solve(ode_solver,op_Af,u₀,t₀,T)
    tiempos=[]
    soluciones=Array{Float64}[]
    ndcoor,u=solucion_en_malla(Ω,u₀)
    matA=pasar_a_cartesianas(ndcoor,u,dx,dy)
    append!(soluciones,[matA])
    append!(tiempos,t₀)
    for (uₕ,t) in uₕₜ
        ndcoor,u=solucion_en_malla(Ω,uₕ)
        matA=pasar_a_cartesianas(ndcoor,u,dx,dy)
        append!(soluciones,[matA])
        append!(tiempos,t)
    end    
    return tiempos,soluciones
end
# Out:
# resolver_calor (generic function with 1 method)

# %%
model = GmshDiscreteModel("geometria.msh")
#writevtk(model,"model")
order = 1
reffe = ReferenceFE(lagrangian,Float64,order)
V0 = TestFESpace(model,reffe;conformity=:H1,dirichlet_tags=["Dv1","Dv2"])
degree = 2
Ω = Triangulation(model)
dΩ = Measure(Ω,degree)
neumanntags = ["Neumman"]
Γ = BoundaryTriangulation(model,tags=neumanntags)
dΓ = Measure(Γ,degree)
# Out:
# Info    : Reading 'geometria.msh'...
# Info    : 11 entities
# Info    : 2601 nodes
# Info    : 5200 elements
# Info    : Done reading 'geometria.msh'
# Measure()

# %%
function S(x,t,posc)
    c=posc(t)
    if abs(c[1]-x[1])<0.1 && abs(c[2]-x[2])<0.1
        return 200.0
    else
        return 0.0
    end
end
# Out:
# S (generic function with 1 method)

# %%
function T1_aux(t,pol, tiempos)
    i=findlast(x->(x<=t), tiempos)
    if pol[i]=="OO" || pol[i]=="OF"
        return -0.5
    else
        return 0.0
    end
end

function T2_aux(t,pol, tiempos)
    i=findlast(x->(x<=t), tiempos)
    if pol[i]=="OO" || pol[i]=="FO"
        return -0.5
    else
        return 0.0
    end
end

function vax(t,x,pol, tiempos)
    i=findlast(x->(x<=t), tiempos)
    if pol[i]=="OO"
        return VectorValue(0.0,5.0)
    elseif pol[i]=="OF"
        if x[1]<0.5
            return VectorValue(0.0,5.0)
        else
            return VectorValue(0.0,0.0)
        end
    elseif pol[i]=="FO"
        if x[1]>0.5
            return VectorValue(0.0,5.0)
        else
            return VectorValue(0.0,0.0)
        end
    else
        return VectorValue(0.0,0.0)
    end
end
# Out:
# vax (generic function with 1 method)

# %%
np = pyimport("numpy")
function generar_muestras(Pec,model,V0,Ω,dΩ,Γ,dΓ,dx,dy,Ndeci,Tf)
    findnearest(A::AbstractArray,t) = findmin(abs.(A.-t))[2]
    for inte in 501:600
        println(inte)
        pol=append!(["FF"],StatsBase.sample(["OO","OF","FO","FF"],Ndeci))
        tiempos2=LinRange(0.0, Tf, Ndeci+1)
        x0=rand()
        y0=0.4+0.6*rand()
        posc(t::Real)=(x0-0.1*t,y0-0.1*t)
        T1f(t::Real)=T1_aux(t,pol, tiempos2)
        T2f(t::Real)=T2_aux(t,pol, tiempos2)
        St(t::Real)= x -> S(x,t,posc)
        vg(t::Real)=x ->vax(t,x,pol, tiempos2)
        @time temps,soluciones=resolver_calor(Pec,T1f,T2f,St,vg,model,V0,Ω,dΩ,Γ,dΓ,dx,dy,0.05,Tf);
        indes=[findnearest(temps,t) for t in tiempos2]
        save("data/soluciones/sol"*string(inte)*".jld", "t", tiempos2, "sol",soluciones[indes],"centroS",posc.(tiempos2),"pol",pol)
        if mod(inte,10)==0
            np.savez("data/anim/sol"*string(inte)*".npz", sol=np.asarray(soluciones), t= np.asarray(temps), centroS=np.asarray(posc.(temps)),tiemposDeci=np.asarray(tiempos2),pol=np.asarray(pol))
        end    
    end
end
# Out:
# generar_muestras (generic function with 1 method)

# %%
generar_muestras(1.0,model,V0,Ω,dΩ,Γ,dΓ,1.0/50.0,1.0/50.0,20,10.0)
# Out:
# 501
#  24.476935 seconds (158.10 M allocations: 11.339 GiB, 10.97% gc time, 65.13% compilation time)
# 502
#   8.932766 seconds (107.47 M allocations: 8.579 GiB, 21.90% gc time, 1.21% compilation time)
# 503
#   8.651481 seconds (107.39 M allocations: 8.575 GiB, 21.47% gc time, 0.07% compilation time)
# 504
#   8.456057 seconds (107.38 M allocations: 8.574 GiB, 17.00% gc time)
# 505
#   8.452878 seconds (107.38 M allocations: 8.575 GiB, 17.14% gc time)
# 506
#   8.461778 seconds (107.38 M allocations: 8.574 GiB, 17.09% gc time)
# 507
#   8.527876 seconds (107.37 M allocations: 8.574 GiB, 16.58% gc time)
# 508
#   8.851022 seconds (107.38 M allocations: 8.575 GiB, 16.74% gc time)
# 509
#   8.238980 seconds (107.38 M allocations: 8.575 GiB, 16.75% gc time)
# 510
#   8.684005 seconds (107.38 M allocations: 8.575 GiB, 16.82% gc time)
# 511
#   8.528899 seconds (107.38 M allocations: 8.575 GiB, 17.33% gc time)
# 512
#   8.663988 seconds (107.38 M allocations: 8.574 GiB, 17.34% gc time)
# 513
#   8.738590 seconds (107.38 M allocations: 8.574 GiB, 17.24% gc time)
# 514
#   8.755790 seconds (107.38 M allocations: 8.575 GiB, 16.98% gc time)
# 515
#   9.214236 seconds (107.38 M allocations: 8.574 GiB, 16.86% gc time)
# 516
#   9.296198 seconds (107.38 M allocations: 8.574 GiB, 16.61% gc time)
# 517
#   8.860575 seconds (107.38 M allocations: 8.574 GiB, 16.90% gc time)
# 518
#   8.877520 seconds (107.38 M allocations: 8.574 GiB, 16.91% gc time)
# 519
#   8.915667 seconds (107.38 M allocations: 8.574 GiB, 16.94% gc time)
# 520
#   8.996070 seconds (107.38 M allocations: 8.574 GiB, 16.52% gc time)
# 521
#   9.022039 seconds (107.38 M allocations: 8.574 GiB, 16.56% gc time)
# 522
#   9.031726 seconds (107.38 M allocations: 8.575 GiB, 16.78% gc time)
# 523
#   8.870387 seconds (107.38 M allocations: 8.574 GiB, 19.97% gc time)
# 524
#   7.838530 seconds (107.38 M allocations: 8.574 GiB, 15.18% gc time)
# 525
#   7.796810 seconds (107.38 M allocations: 8.575 GiB, 15.02% gc time)
# 526
#   7.777947 seconds (107.38 M allocations: 8.574 GiB, 14.69% gc time)
# 527
#   7.859771 seconds (107.38 M allocations: 8.575 GiB, 14.53% gc time)
# 528
#   7.885172 seconds (107.38 M allocations: 8.574 GiB, 14.16% gc time)
# 529
#   7.754915 seconds (107.38 M allocations: 8.575 GiB, 14.19% gc time)
# 530
#   7.903919 seconds (107.38 M allocations: 8.574 GiB, 14.36% gc time)
# 531
#   8.549099 seconds (107.38 M allocations: 8.575 GiB, 14.33% gc time)
# 532
#   8.605102 seconds (107.38 M allocations: 8.574 GiB, 14.74% gc time)
# 533
#   8.684010 seconds (107.38 M allocations: 8.574 GiB, 14.78% gc time)
# 534
#   8.508586 seconds (107.38 M allocations: 8.574 GiB, 14.76% gc time)
# 535
#   8.297253 seconds (107.38 M allocations: 8.575 GiB, 15.03% gc time)
# 536
#   8.182039 seconds (107.38 M allocations: 8.575 GiB, 15.06% gc time)
# 537
#   8.262891 seconds (107.38 M allocations: 8.574 GiB, 15.13% gc time)
# 538
#   8.282174 seconds (107.38 M allocations: 8.575 GiB, 15.04% gc time)
# 539
#   8.311544 seconds (107.38 M allocations: 8.575 GiB, 15.30% gc time)
# 540
#   8.384579 seconds (107.38 M allocations: 8.574 GiB, 15.20% gc time)
# 541
#   8.440404 seconds (107.38 M allocations: 8.575 GiB, 14.97% gc time)
# 542
#   8.456626 seconds (107.38 M allocations: 8.575 GiB, 15.12% gc time)
# 543
#   8.774562 seconds (107.38 M allocations: 8.575 GiB, 19.43% gc time)
# 544
#   9.531881 seconds (107.38 M allocations: 8.574 GiB, 13.64% gc time)
# 545
#   8.575680 seconds (107.38 M allocations: 8.575 GiB, 13.98% gc time)
# 546
#   7.813312 seconds (107.38 M allocations: 8.575 GiB, 14.50% gc time)
# 547
#   7.806243 seconds (107.38 M allocations: 8.574 GiB, 14.37% gc time)
# 548
#   7.830631 seconds (107.38 M allocations: 8.575 GiB, 14.06% gc time)
# 549
#   7.772233 seconds (107.38 M allocations: 8.574 GiB, 14.33% gc time)
# 550
#   7.847022 seconds (107.38 M allocations: 8.575 GiB, 14.51% gc time)
# 551
#   7.924899 seconds (107.37 M allocations: 8.574 GiB, 14.71% gc time)
# 552
#   7.982923 seconds (107.38 M allocations: 8.574 GiB, 14.90% gc time)
# 553
#   8.044709 seconds (107.38 M allocations: 8.575 GiB, 14.98% gc time)
# 554
#   8.069732 seconds (107.38 M allocations: 8.574 GiB, 14.90% gc time)
# 555
#   8.192652 seconds (107.38 M allocations: 8.575 GiB, 15.20% gc time)
# 556
#   8.301162 seconds (107.38 M allocations: 8.574 GiB, 14.98% gc time)
# 557
#   8.291930 seconds (107.38 M allocations: 8.575 GiB, 15.29% gc time)
# 558
#   8.317594 seconds (107.38 M allocations: 8.575 GiB, 15.29% gc time)
# 559
#   8.896472 seconds (107.38 M allocations: 8.575 GiB, 15.21% gc time)
# 560
#   9.200933 seconds (107.38 M allocations: 8.574 GiB, 15.10% gc time)
# 561
#   8.921729 seconds (107.38 M allocations: 8.574 GiB, 15.34% gc time)
# 562
#   9.190697 seconds (107.38 M allocations: 8.575 GiB, 15.04% gc time)
# 563
#   9.137068 seconds (107.38 M allocations: 8.574 GiB, 19.19% gc time)
# 564
#   8.160022 seconds (107.38 M allocations: 8.575 GiB, 15.14% gc time)
# 565
#   8.169566 seconds (107.38 M allocations: 8.575 GiB, 14.66% gc time)
# 566
#   7.817494 seconds (107.38 M allocations: 8.575 GiB, 14.34% gc time)
# 567
#   8.587584 seconds (107.38 M allocations: 8.575 GiB, 13.95% gc time)
# 568
#   8.121670 seconds (107.38 M allocations: 8.574 GiB, 14.07% gc time)
# 569
#   8.349844 seconds (107.38 M allocations: 8.574 GiB, 14.19% gc time)
# 570
#   8.049674 seconds (107.38 M allocations: 8.574 GiB, 14.43% gc time)
# 571
#   7.968882 seconds (107.38 M allocations: 8.575 GiB, 14.76% gc time)
# 572
#   8.026837 seconds (107.38 M allocations: 8.574 GiB, 15.02% gc time)
# 573
#   8.092698 seconds (107.38 M allocations: 8.574 GiB, 15.04% gc time)
# 574
#   8.125952 seconds (107.38 M allocations: 8.574 GiB, 15.12% gc time)
# 575
#   8.456350 seconds (107.38 M allocations: 8.574 GiB, 15.20% gc time)
# 576
#   8.254412 seconds (107.38 M allocations: 8.575 GiB, 15.27% gc time)
# 577
#   8.240576 seconds (107.38 M allocations: 8.575 GiB, 15.05% gc time)
# 578
#   8.359511 seconds (107.38 M allocations: 8.574 GiB, 15.16% gc time)
# 579
#   8.628995 seconds (107.38 M allocations: 8.574 GiB, 15.36% gc time)
# 580
#   8.727456 seconds (107.38 M allocations: 8.574 GiB, 15.00% gc time)
# 581
#   8.549575 seconds (107.38 M allocations: 8.574 GiB, 15.34% gc time)
# 582
#   8.650921 seconds (107.38 M allocations: 8.574 GiB, 15.11% gc time)
# 583
#   8.574018 seconds (107.38 M allocations: 8.574 GiB, 15.08% gc time)
# 584
#   8.500603 seconds (107.38 M allocations: 8.575 GiB, 19.32% gc time)
# 585
#   8.244102 seconds (107.38 M allocations: 8.575 GiB, 14.98% gc time)
# 586
#   7.959392 seconds (107.38 M allocations: 8.574 GiB, 14.41% gc time)
# 587
#   7.786646 seconds (107.38 M allocations: 8.575 GiB, 14.57% gc time)
# 588
#   7.766018 seconds (107.38 M allocations: 8.574 GiB, 14.30% gc time)
# 589
#   7.808026 seconds (107.38 M allocations: 8.574 GiB, 14.30% gc time)
# 590
#   7.880473 seconds (107.38 M allocations: 8.575 GiB, 14.39% gc time)
# 591
#   8.315300 seconds (107.38 M allocations: 8.575 GiB, 14.37% gc time)
# 592
#   8.562981 seconds (107.38 M allocations: 8.574 GiB, 14.58% gc time)
# 593
#   8.505969 seconds (107.38 M allocations: 8.574 GiB, 14.73% gc time)
# 594
#   8.470925 seconds (107.38 M allocations: 8.575 GiB, 14.93% gc time)
# 595
#   8.516730 seconds (107.38 M allocations: 8.574 GiB, 15.10% gc time)
# 596
#   8.646781 seconds (107.38 M allocations: 8.575 GiB, 15.22% gc time)
# 597
#   8.663690 seconds (107.38 M allocations: 8.575 GiB, 15.42% gc time)
# 598
#   8.709288 seconds (107.38 M allocations: 8.575 GiB, 15.20% gc time)
# 599
#   8.827597 seconds (107.38 M allocations: 8.575 GiB, 15.23% gc time)
# 600
#   8.681304 seconds (107.37 M allocations: 8.574 GiB, 15.11% gc time)
